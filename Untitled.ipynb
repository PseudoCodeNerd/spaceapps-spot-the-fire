# %%
# !pwd
# Out:
# /home/pseudocodenerd/Desktop/code/phoenix/ml

# %%
import csv
import pandas as pd

# %%
modis_usa = pd.read_csv("pre_data/MODIS_C6_USA_contiguous_and_Hawaii_7d.csv")
modis_usa.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0    39.884    -78.246       300.3   1.4    1.2  2020-09-26       255
# 1    18.639    -96.216       308.0   1.4    1.2  2020-09-26       425
# 2    40.595   -105.702       303.1   1.9    1.4  2020-09-26       435
# 3    40.696   -105.729       322.6   1.9    1.3  2020-09-26       435
# 4    40.705   -105.718       321.3   1.9    1.3  2020-09-26       435
#
#   satellite  confidence version  bright_t31   frp daynight
# 0         T          24  6.0NRT       284.0  10.4        N
# 1         T          73  6.0NRT       291.3  10.4        N
# 2         T          53  6.0NRT       278.5  23.4        N
# 3         T          77  6.0NRT       283.9  54.7        N
# 4         T          39  6.0NRT       282.8  49.1        N

# %%
modis_txt_test = pd.read_csv("pre_data/FIRMS/c6/USA_contiguous_and_Hawaii/MODIS_C6_USA_contiguous_and_Hawaii_MCD14DL_NRT_2020217.txt", 
                             names=['Latitude', 'Longitude', 'Brightness', 'Scan', 'TRACK', 'acq_data', 'acq_time', 'satellite', 'confidence', 'version',
                                   'bright', 'FIRE RADIATIVE POWER', 'day or night'], skiprows=1, sep=',')

# %% [markdown]
# ### Attributes of each MODIS text file
# ![image.png](attachment:image.png)

# %%
modis_txt_test.head(15)
# Out:
#     Latitude  Longitude  Brightness  Scan  TRACK    acq_data acq_time  \
# 0     29.754    -95.019       315.7   1.4    1.2  2020-08-04    04:10
# 1     29.761    -95.011       308.4   1.4    1.2  2020-08-04    04:10
# 2     30.944    -88.013       308.1   1.2    1.1  2020-08-04    04:10
# 3     31.150    -87.985       305.9   1.2    1.1  2020-08-04    04:10
# 4     33.441    -88.569       304.4   1.2    1.1  2020-08-04    04:10
# 5     18.286    -88.310       309.4   1.0    1.0  2020-08-04    04:10
# 6     27.041    -85.941       310.7   1.3    1.1  2020-08-04    04:10
# 7     29.757    -95.004       336.0   1.4    1.2  2020-08-04    04:10
# 8     36.096    -93.165       301.0   1.0    1.0  2020-08-04    04:15
# 9     36.463    -92.042       302.2   1.0    1.0  2020-08-04    04:15
# 10    35.809    -94.453       302.0   1.1    1.0  2020-08-04    04:15
# 11    35.888    -89.785       302.6   1.1    1.0  2020-08-04    04:15
# 12    34.988    -94.608       301.6   1.1    1.1  2020-08-04    04:15
# 13    36.094    -93.176       303.8   1.0    1.0  2020-08-04    04:15
# 14    31.866   -115.890       303.9   1.0    1.0  2020-08-04    05:50
#
#    satellite  confidence version  bright  FIRE RADIATIVE POWER day or night
# 0          T          92  6.0NRT   293.2                  16.6            N
# 1          T          74  6.0NRT   294.4                   8.7            N
# 2          T          72  6.0NRT   295.3                   8.3            N
# 3          T          66  6.0NRT   295.8                   6.5            N
# 4          T          60  6.0NRT   293.8                   6.0            N
# 5          T          76  6.0NRT   292.8                   6.7            N
# 6          T          72  6.0NRT   296.4                   9.5            N
# 7          T         100  6.0NRT   295.0                  56.4            N
# 8          T          35  6.0NRT   287.1                   6.0            N
# 9          T          47  6.0NRT   290.1                   5.1            N
# 10         T          46  6.0NRT   289.3                   6.4            N
# 11         T          50  6.0NRT   292.3                   4.8            N
# 12         T          43  6.0NRT   290.4                   5.4            N
# 13         T          57  6.0NRT   285.6                   7.6            N
# 14         T          18  6.0NRT   292.3                   4.7            N
